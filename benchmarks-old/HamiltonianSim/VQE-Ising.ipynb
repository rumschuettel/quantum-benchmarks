# %% [markdown]
# # Hamiltonian Simulation
# ## VQE Solution to a Spin Hamiltonian's Ground State, Plotted Qubistically

# %% [markdown]
# This is a VQE solver for a spin Hamiltonian's ground state; tutorial see
#
# https://github.com/Qiskit/qiskit-tutorials/blob/master/community/aqua/algorithm_introduction_with_vqe.ipynb

# %%
from qiskit.aqua import Operator
import pprint
pp = pprint.PrettyPrinter().pprint
from math import log

# %%
# next-to-nearest neighbour Heisenberg Hamiltonian
# scaled such that critical point at J2=.5
def Paulis_Heisenberg_NNN(N, J2, J1=1., verbose=False):
    terms = {
        'paulis': [
            list(h for h in [
                {'label': 'I'*i + 'XX' + 'I'*(N-i-2), 'coeff': {'real': J1, 'imag': 0}},
                {'label': 'I'*i + 'YY' + 'I'*(N-i-2), 'coeff': {'real': J1, 'imag': 0}},
                {'label': 'I'*i + 'ZZ' + 'I'*(N-i-2), 'coeff': {'real': J1, 'imag': 0}}
            ])
            for i in range(0, N-1)
        ] + [
            list(h for h in [
                {'label': 'I'*i + 'XIX' + 'I'*(N-i-3), 'coeff': {'real': J2, 'imag': 0}},
                {'label': 'I'*i + 'YIY' + 'I'*(N-i-3), 'coeff': {'real': J2, 'imag': 0}},
                {'label': 'I'*i + 'ZIZ' + 'I'*(N-i-3), 'coeff': {'real': J2, 'imag': 0}}
            ])
            for i in range(0, N-2)
        ]
    }
    terms['paulis'] = [ h for hh in terms['paulis'] for h in hh ]
    
    if verbose: pp(terms['paulis'])
    
    return Operator.load_from_dict(terms)

Paulis_Heisenberg_NNN(8, .4)

# %%
# nearest neighbour transverse-field Ising
# scaled such that critical point at Γ=.5
def Paulis_TIM_NN(N, Γ, J=.5, verbose=False):
    terms = {
        'paulis': [
            list(h for h in [
                {'label': 'I'*i + 'ZZ' + 'I'*(N-i-2), 'coeff': {'real': J, 'imag': 0}}
            ])
            for i in range(0, N-1)
        ] + [
            list(h for h in [
                {'label': 'I'*i + 'X' + 'I'*(N-i-1), 'coeff': {'real': -Γ, 'imag': 0}}
            ])
            for i in range(0, N)
        ]
    }
    terms['paulis'] = [ h for hh in terms['paulis'] for h in hh ]
    
    if verbose: pp(terms['paulis'])
    
    return Operator.load_from_dict(terms)

Paulis_TIM_NN(4, .5)

# %% [markdown]
# ## QUBISM Plot

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def qubism_indices(depth):
    def _qubism_indices(depth, prefix):
        if depth == 0:
            return prefix

        return np.block([[
            _qubism_indices(depth-1, prefix+'00'), _qubism_indices(depth-1, prefix+'01')
        ], [
            _qubism_indices(depth-1, prefix+'10'), _qubism_indices(depth-1, prefix+'11')
        ]])

    arr = np.array(_qubism_indices(depth, ''))
    f = np.vectorize(lambda s: int(s, 2))
    
    return f(arr)
        
qubism_indices(3)
# Out:
# array([[ 0,  1,  4,  5, 16, 17, 20, 21],
#        [ 2,  3,  6,  7, 18, 19, 22, 23],
#        [ 8,  9, 12, 13, 24, 25, 28, 29],
#        [10, 11, 14, 15, 26, 27, 30, 31],
#        [32, 33, 36, 37, 48, 49, 52, 53],
#        [34, 35, 38, 39, 50, 51, 54, 55],
#        [40, 41, 44, 45, 56, 57, 60, 61],
#        [42, 43, 46, 47, 58, 59, 62, 63]])

# %%
def qubism_array(vector, verbose=False):
    base4exp = log(len(vector), 4)
    assert base4exp > 0 and base4exp % 1 == 0., "input has to be vector of length 4^n"
    
    if verbose: print('qubism size: ', 2*base4exp, 'x', 2*base4exp)
    indices = qubism_indices(base4exp)
    shuffled = np.array(vector)[indices]
    
    return np.abs(shuffled)

# %%
def qubism_plot(vector, vmax_vec=None, plot=None):
    # bias somewhat so that small numbers show up stronger
    vector_mapped = np.power(vector, .5)
    # take maximum range from own vector by default
    vmax_vec = vector_mapped if not isinstance(vmax_vec, np.ndarray) else np.power(vmax_vec, .5)
    vmax = np.max(np.abs(vmax_vec))
    
    if plot == None:
        fig, plot = plt.subplots(1, 1, figsize=(8,8))
        
    plot.set_xticks([], []) 
    plot.set_yticks([], [])
    plot.imshow(qubism_array(vector_mapped), cmap='viridis', vmin=0, vmax=vmax)

# %% [markdown]
# ## Solve Exactly

# %%
from qiskit.aqua.algorithms import ExactEigensolver

# %%
exact_eigensolver = ExactEigensolver(Paulis_TIM_NN(14, .8))
result_cl = exact_eigensolver.run()

print(result_cl['energy'])
# Out:
# -12.238512061010736

# %%
qubism_plot(result_cl['wavefunction'][0])

# %% [markdown]
# ## VQE

# %%
from qiskit.aqua import run_algorithm
from qiskit.aqua.input import EnergyInput

# %%
def AquaCfgDict(depth, rounds, method='SLSQP', optimizer_rounds_name='maxiter'):
    return {
        'algorithm': {
            'name': 'VQE',
            'operator_mode': 'matrix'
        },
        'variational_form': {
            'name': 'RYRZ',
            'depth': rounds,
            'entanglement': 'full'
        },
        'optimizer': {
            'name': method,
            optimizer_rounds_name: rounds
        },
        'backend': {
            'name': 'statevector_simulator',
            'provider': 'qiskit.BasicAer'
        }
    }

# %%
algo_input = EnergyInput(Paulis_Heisenberg_NNN(2, .8))
result_q = run_algorithm(AquaCfgDict(2, 500), algo_input)

print(result_q['energy'])
# Out:
# -2.9999999999992633

# %%
qubism_plot(result_q['min_vector'], result_cl['wavefunction'][0])
qubism_plot(result_cl['wavefunction'][0])

# %% [markdown]
# ## On-Device

# %% [markdown]
# # Reference Plots

# %%
import matplotlib.gridspec as gridspec

# %%
HAMILTONIAN_PARAMS = [0., .25, .4, .466, .5, .533, .6, .75, 1.]

# %%
# data collection
# this is fast, no need to save
results_exact = {}
for N in [2, 4, 6, 8, 10, 12, 14, 16]:
    for ham_id, factory in [('heisenberg', Paulis_Heisenberg_NNN), ('ising', Paulis_TIM_NN)]:
        for param in HAMILTONIAN_PARAMS:
            key = (N,ham_id,param)
            entry = results_exact[key] = {}
    
            # local operators
            paulis = factory(N, param)
            
            # EXACT
            # diagonalize exactly, we only need to do this once
            exact_eigensolver = ExactEigensolver(paulis)
            result_cl = exact_eigensolver.run()

            entry['exact'] = {
                'energy': result_cl['energy'],
                'state': result_cl['wavefunction'][0]
            }

# %%
# plotting
def index_2d(ll, v):
    for i, x in enumerate(ll):
        if v in x: return (i, x.index(v))
        
layout_lookup = [[
    (N, param)
    for N in [2, 4, 6, 8, 10, 12, 14, 16]
] for param in HAMILTONIAN_PARAMS]

print(index_2d(layout_lookup,(4, .25)))
# Out:
# (1, 1)

# %%
plt.axis('off')
plt.tight_layout()

fig = plt.figure(figsize=(8, 9))
nx = len(layout_lookup)
ny = len(layout_lookup[0])
outer = gridspec.GridSpec(nx, ny, wspace=0.2, hspace=0.2)

for key in results_exact:
    N, ham_id, param = key 
    if ham_id != 'ising': continue
        
    cx,cy = index_2d(layout_lookup, (N, param))
    entry = results_exact[key]
    
    plot = plt.Subplot(fig, outer[cx, cy])
    qubism_plot(entry['exact']['state'], plot=plot)
    fig.add_subplot(plot)
    

fig.savefig(r'vqe-ising-exact.pdf', bbox_inches='tight', dpi=600)

# %% [markdown]
# # Benchmark

# %% [markdown]
# ## Automated Plots and Runs for the IBM Q Experience

# %%
# data collection
results = {}
for N in [2, 4, 6]:
    for ham_id, factory in [('heisenberg', Paulis_Heisenberg_NNN), ('ising', Paulis_TIM_NN)]:
        for param in HAMILTONIAN_PARAMS:
            key = (N,ham_id,param)
            entry = results[key] = {}
    
            # local operators
            paulis = factory(N, param)
            
            # EXACT
            # diagonalize exactly, we only need to do this once
            exact_eigensolver = ExactEigensolver(paulis)
            result_cl = exact_eigensolver.run()

            print(key, result_cl['energy'])
            entry['exact'] = {
                'energy': result_cl['energy'],
                'state': result_cl['wavefunction'][0]
            }
            
            # SIMULATION
            # we run a few rounds, each one will choose its own starting point
            entry['simulation'] = { 'energy': 10**10 }
            
            def simulation_instance(run):
                algo_input = EnergyInput(paulis)
                result_sim = run_algorithm(AquaCfgDict(N, 1500*N, method='SLSQP'), algo_input)

                energy = result_sim['energy']
                if energy < entry['simulation']['energy']:
                    print('found best energy in run', run, ': ', result_sim['energy'])
                    entry['simulation'] = {
                        'energy': result_sim['energy'],
                        'state': result_sim['min_vector']
                    }
            
            # TODO: parallelize
            for run in range(10):
                simulation_instance(run)
                
            # IBM Q Run
            pass
# Out:
# (2, 'heisenberg', 0.0) -3.0
# found best energy in run 0 :  -2.99999990006502
# found best energy in run 2 :  -2.9999999763225595
# found best energy in run 5 :  -2.9999999765236702
# found best energy in run 6 :  -2.9999999994951017
# (2, 'heisenberg', 0.25) -3.0000000000000004
# found best energy in run 0 :  -2.9999998821538414
# found best energy in run 1 :  -2.999999922651825
# found best energy in run 2 :  -2.999999987497889
# found best energy in run 3 :  -2.9999999898369456
# found best energy in run 6 :  -2.9999999966310114
# (2, 'heisenberg', 0.4) -3.0
# found best energy in run 0 :  -2.9999999999993987
# (2, 'heisenberg', 0.466) -3.000000000000001
# found best energy in run 0 :  -2.999999955118434
# found best energy in run 1 :  -2.9999999925479175
# found best energy in run 2 :  -2.9999999943852456
# found best energy in run 6 :  -2.9999999963288655
# found best energy in run 7 :  -2.99999999651328
# found best energy in run 8 :  -2.9999999983588532
# (2, 'heisenberg', 0.5) -3.0
# found best energy in run 0 :  -2.9999998392184386
# found best energy in run 1 :  -2.999999959053067
# found best energy in run 4 :  -2.999999962025536
# found best energy in run 6 :  -2.9999999953291008
# found best energy in run 8 :  -2.9999999974014915
# (2, 'heisenberg', 0.533) -3.000000000000001
# found best energy in run 0 :  -2.9999992363404484
# found best energy in run 1 :  -2.9999997146971102
# found best energy in run 2 :  -2.9999999723839745
# found best energy in run 3 :  -2.9999999814538225
# found best energy in run 5 :  -2.9999999932994013
# (2, 'heisenberg', 0.6) -3.0
# found best energy in run 0 :  -2.999999893171398
# found best energy in run 1 :  -2.999999972426574
# found best energy in run 2 :  -2.9999999999986295
# (2, 'heisenberg', 0.75) -3.0
# found best energy in run 0 :  -2.99999995990542
# found best energy in run 1 :  -2.9999999616452806
# found best energy in run 2 :  -2.99999999484353
# found best energy in run 3 :  -2.9999999964352044
# found best energy in run 6 :  -2.999999999830873
# (2, 'heisenberg', 1.0) -3.0
# found best energy in run 0 :  -2.9999999944115183
# found best energy in run 4 :  -2.9999999999714246
# (2, 'ising', 0.0) -0.5
# found best energy in run 0 :  -0.4999999746444153
# found best energy in run 2 :  -0.4999999977298355
# (2, 'ising', 0.25) -0.7071067811865474
# found best energy in run 0 :  -0.7071067686565202
# (2, 'ising', 0.4) -0.9433981132056605
# found best energy in run 0 :  -0.9433978328100483
# found best energy in run 1 :  -0.9433980917624217
# found best energy in run 8 :  -0.943398107189573
# found best energy in run 9 :  -0.9433981127407647
# (2, 'ising', 0.466) -1.0576502257362774
# found best energy in run 0 :  -1.0576501311124213
# found best energy in run 2 :  -1.0576501625584074
# found best energy in run 3 :  -1.0576501640789628
# (2, 'ising', 0.5) -1.1180339887498958
# found best energy in run 0 :  -1.1180337419341089
# found best energy in run 1 :  -1.1180339763791092
# (2, 'ising', 0.533) -1.1774361978468302
# found best energy in run 0 :  -1.1774361344399327
# found best energy in run 3 :  -1.1774361827304085
# found best energy in run 6 :  -1.1774361956006878
# (2, 'ising', 0.6) -1.3000000000000005
# found best energy in run 0 :  -1.299999952940951
# found best energy in run 1 :  -1.2999999951791061
# (2, 'ising', 0.75) -1.5811388300841902
# found best energy in run 0 :  -1.5811387827437104
# found best energy in run 3 :  -1.581138816985094
# (2, 'ising', 1.0) -2.0615528128088285
# found best energy in run 0 :  -2.0615526203320274
# found best energy in run 2 :  -2.06155277976199
# found best energy in run 4 :  -2.0615528025110157
# found best energy in run 6 :  -2.0615528120997926
# (4, 'heisenberg', 0.0) -6.464101615137751
# found best energy in run 0 :  -6.4641002947550446
# found best energy in run 3 :  -6.464101517371908
# (4, 'heisenberg', 0.25) -6.145751311064577
# found best energy in run 0 :  -6.145749600383176
# found best energy in run 3 :  -6.145750433749985
# found best energy in run 9 :  -6.145750699505486
# (4, 'heisenberg', 0.4) -6.027105745132013
# found best energy in run 0 :  -6.027098994043513
# found best energy in run 3 :  -6.027105533728596
# (4, 'heisenberg', 0.466) -6.003351249788403
# found best energy in run 0 :  -6.003315662690409
# found best energy in run 6 :  -6.0033177546125005
# found best energy in run 8 :  -6.003325904977689
# (4, 'heisenberg', 0.5) -6.000000000000002
# found best energy in run 0 :  -5.9999995388410845
# found best energy in run 1 :  -5.999999981572805
# (4, 'heisenberg', 0.533) -6.003375544389885
# found best energy in run 0 :  -6.003360652086322
# found best energy in run 2 :  -6.003367847123494
# found best energy in run 6 :  -6.0033751620269635
# (4, 'heisenberg', 0.6) -6.033030277982335
# found best energy in run 0 :  -6.014657780273468
# found best energy in run 1 :  -6.0330250672370305
# found best energy in run 2 :  -6.033027496281955
# found best energy in run 7 :  -6.0330300787507545
# (4, 'heisenberg', 0.75) -6.232050807568873
# found best energy in run 0 :  -6.232045078530726
# found best energy in run 1 :  -6.232049755696533
# found best energy in run 3 :  -6.2320498291543664
# found best energy in run 5 :  -6.232050317170751
# found best energy in run 7 :  -6.232050654434687
# (4, 'heisenberg', 1.0) -7.0
# found best energy in run 0 :  -6.99987177671078
# found best energy in run 1 :  -6.999999782869887
# (4, 'ising', 0.0) -1.5
# found best energy in run 0 :  -1.4999995944593385
# found best energy in run 5 :  -1.4999996153795283
# found best energy in run 6 :  -1.4999998482518553
# (4, 'ising', 0.25) -1.7135170444540424
# found best energy in run 0 :  -1.6915434315340068
# found best energy in run 1 :  -1.7135150077277974
# found best energy in run 2 :  -1.7135163901440138
# (4, 'ising', 0.4) -2.0727804566585464
# found best energy in run 0 :  -2.0727783852561377
# found best energy in run 4 :  -2.0727799598885825
# (4, 'ising', 0.466) -2.2709956798933275
# found best energy in run 0 :  -2.27092666891199
# found best energy in run 1 :  -2.270994935760245
# found best energy in run 6 :  -2.270994993203689
# (4, 'ising', 0.5) -2.379385241571818
# found best energy in run 0 :  -2.379357977765224
# found best energy in run 2 :  -2.379384160465745
# found best energy in run 5 :  -2.3793848824474892
# (4, 'ising', 0.533) -2.4878135462091486
# found best energy in run 0 :  -2.487812240006014
# found best energy in run 3 :  -2.4878130989851095
# (4, 'ising', 0.6) -2.715759791368741
# found best energy in run 0 :  -2.7157465534662952
# found best energy in run 1 :  -2.7157580693618644
# found best energy in run 7 :  -2.71575925278733
# (4, 'ising', 0.75) -3.251945778563199
# found best energy in run 0 :  -3.251881338677768
# found best energy in run 1 :  -3.2519354234661906
# found best energy in run 7 :  -3.251938384131961
# found best energy in run 8 :  -3.251941603219622
# (4, 'ising', 1.0) -4.188399318425173
# found best energy in run 0 :  -4.188375663547623
# found best energy in run 2 :  -4.188390443305337
# (6, 'heisenberg', 0.0) -9.974308535551721
# found best energy in run 0 :  -9.699346762166742
# found best energy in run 1 :  -9.918010886783758
# found best energy in run 3 :  -9.941917992435368
# (6, 'heisenberg', 0.25) -9.3217935453467
# found best energy in run 0 :  -9.18058176462571
# found best energy in run 5 :  -9.242944198411884
# found best energy in run 6 :  -9.245147548107727
# found best energy in run 9 :  -9.283682705204907
# (6, 'heisenberg', 0.4) -9.062139520350796
# found best energy in run 0 :  -9.018442354763875
# found best energy in run 1 :  -9.036979106870534
# found best energy in run 3 :  -9.042809188539978
# found best energy in run 7 :  -9.056104517442032
# (6, 'heisenberg', 0.466) -9.00778538217611
# found best energy in run 0 :  -9.00243794437442
# found best energy in run 2 :  -9.004058510334783
# (6, 'heisenberg', 0.5) -8.999999999999993
# found best energy in run 0 :  -8.99999950274924
# found best energy in run 1 :  -8.999999837073672
# found best energy in run 2 :  -8.999999875521574
# found best energy in run 9 :  -8.999999894988285
# (6, 'heisenberg', 0.533) -9.00789091990655
# found best energy in run 0 :  -9.003776581512179
# found best energy in run 3 :  -9.004716008896386
# found best energy in run 7 :  -9.00494640222676
# (6, 'heisenberg', 0.6) -9.076765418344815
# found best energy in run 0 :  -9.048976738409415
# found best energy in run 5 :  -9.063365457739167
# (6, 'heisenberg', 0.75) -9.504794067944708
# found best energy in run 0 :  -9.273945097445418
# found best energy in run 5 :  -9.434049569687263
# (6, 'heisenberg', 1.0) -10.834876250652341
# found best energy in run 0 :  -9.703683026564292
# found best energy in run 1 :  -10.682158687783286
# found best energy in run 4 :  -10.798909141752327
# (6, 'ising', 0.0) -2.5
# found best energy in run 0 :  -2.4999998425469814
# (6, 'ising', 0.25) -2.761014785400112
# found best energy in run 0 :  -2.750571400289717
# found best energy in run 1 :  -2.7530211688356254
# found best energy in run 6 :  -2.7542757538511804
# (6, 'ising', 0.4) -3.219854865375468
# found best energy in run 0 :  -3.150026422180274
# found best energy in run 2 :  -3.206867562290546
# (6, 'ising', 0.466) -3.4943117186182238
# found best energy in run 0 :  -3.4821898541578626
# found best energy in run 2 :  -3.490747434809381
# found best energy in run 7 :  -3.4911020984328385
# (6, 'ising', 0.5) -3.6481149052793738
# found best energy in run 0 :  -3.6467183501793023
# (6, 'ising', 0.533) -3.8037213214577736
# found best energy in run 0 :  -3.7936283869648384
# found best energy in run 1 :  -3.8031732632069275
# found best energy in run 7 :  -3.803258846361867
# (6, 'ising', 0.6) -4.134672174113486
# found best energy in run 0 :  -4.124686117166949
# found best energy in run 1 :  -4.131795878432936
# found best energy in run 3 :  -4.133567932203635
# (6, 'ising', 0.75) -4.92378573557731
# found best energy in run 0 :  -4.847164742133979
# found best energy in run 1 :  -4.921427282290687
# found best energy in run 7 :  -4.921571558231749
# (6, 'ising', 1.0) -6.315482138246514
# found best energy in run 0 :  -6.300874431506596
# found best energy in run 3 :  -6.31422978511741
# found best energy in run 4 :  -6.314429906115401

# %%
# save and load runs
import pickle
with open(r"results-reference.pickle", "wb") as output_file:
    pickle.dump(results, output_file)
    pass

# %%
'''
with open(r"results-reference.pickle", "rb") as input_file:
    print(pickle.load(input_file))
'''
# Out:
# '\nwith open(r"results-reference.pickle", "rb") as input_file:\n    print(pickle.load(input_file))\n'

# %%
# plotting
def index_2d(ll, v):
    for i, x in enumerate(ll):
        if v in x: return (i, x.index(v))
        
layout_lookup = [[
    (N, ham_id, param)
    for ham_id in ['ising', 'heisenberg']
    for N in [2, 4, 6, 42]
] for param in HAMILTONIAN_PARAMS]

print(index_2d(layout_lookup,(2, 'heisenberg', 0)))
# Out:
# (0, 4)

# %%
plt.axis('off')
plt.tight_layout()

fig = plt.figure(figsize=(8, 18))
nx = len(layout_lookup)
ny = len(layout_lookup[0])
outer = gridspec.GridSpec(nx, ny, wspace=0.2, hspace=0.2)

for key in results:
    N, run_id, param = key       
    
    entry = results[key]
    try:
        cx,cy = index_2d(layout_lookup, key)
    except TypeError:
        print(key)
        continue
        
    inner = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=outer[cx, cy], wspace=0.05, hspace=0.05)
    
    plot = plt.Subplot(fig, inner[0])
    qubism_plot(entry['exact']['state'], plot=plot)
    fig.add_subplot(plot)
    
    plot = plt.Subplot(fig, inner[1])
    qubism_plot(entry['simulation']['state'], plot=plot, vmax_vec=entry['exact']['state'])
    fig.add_subplot(plot)
    

fig.savefig(r'vqe-ibm-q-sim.pdf', bbox_inches='tight')
